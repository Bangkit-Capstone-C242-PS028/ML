# %%
import os
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from collections import Counter
import util  # Assuming this is a custom module
# Out:
# 2024-12-12 01:10:28.978935: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-12 01:10:28.992843: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733965829.007650   14538 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733965829.012109   14538 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-12 01:10:29.028725: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Paths to the dataset
train_dir = "../dataset/split_tiga/train"
val_dir = "../dataset/split_tiga/val"
test_dir = "../dataset/split_tiga/test"
IMAGE_DIR = "../dataset/split_tiga/test"

# %%
def count_labels(directory):
    """Count the labels in the dataset directory."""
    label_counts = Counter()
    for class_dir in os.listdir(directory):
        class_path = os.path.join(directory, class_dir)
        if os.path.isdir(class_path):
            label_counts[class_dir] = len(os.listdir(class_path))  # Simplified counting
    return label_counts

# %%
# Count labels for train, val, and test sets
train_counts = count_labels(train_dir)
val_counts = count_labels(val_dir)
test_counts = count_labels(test_dir)

# %%
# Calculate class weights
train_total = sum(train_counts.values())
class_weights = {label: train_total / (len(train_counts) * count) 
                 for label, count in train_counts.items()}

# %%
print("Train label counts:", train_counts)
print("Validation label counts:", val_counts)
print("Test label counts:", test_counts)
print("Class weights:", class_weights)
# Out:
# Train label counts: Counter({'nv': 4693, 'mel': 779, 'bkl': 769, 'bcc': 359, 'akiec': 228, 'vasc': 99, 'df': 80})
# Validation label counts: Counter({'nv': 1006, 'mel': 167, 'bkl': 165, 'bcc': 77, 'akiec': 49, 'vasc': 21, 'df': 17})
# Test label counts: Counter({'nv': 1007, 'mel': 167, 'bkl': 166, 'bcc': 78, 'akiec': 50, 'vasc': 22, 'df': 18})
# Class weights: {'bkl': 1.3016905071521456, 'nv': 0.21329639889196675, 'df': 12.5125, 'mel': 1.2849807445442876, 'vasc': 10.11111111111111, 'bcc': 2.788300835654596, 'akiec': 4.390350877192983}

# %%
# TensorFlow weighted loss function
def weighted_loss(pos_weights, neg_weights):
    """Create a weighted loss function."""
    def loss_fn(y_true, y_pred):
        pos_loss = -pos_weights * y_true * tf.math.log(y_pred + tf.keras.backend.epsilon())
        neg_loss = -neg_weights * (1 - y_true) * tf.math.log(1 - y_pred + tf.keras.backend.epsilon())
        return tf.reduce_mean(pos_loss + neg_loss)
    return loss_fn

# %%
# --- Model Definition and Compilation ---
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3)) 
x = base_model.output
x = GlobalAveragePooling2D()(x)
labels = list(train_counts.keys())
# Out:
# I0000 00:00:1733965838.312966   14538 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43629 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:64:00.0, compute capability: 8.9

# %%
# If you have pre-calculated weights, use them here
pos_weights = np.array([class_weights[label] for label in labels]) 
neg_weights = np.ones(len(labels)) 

predictions = Dense(len(labels), activation="sigmoid")(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# Compile the model
model.compile(optimizer='adam', loss=weighted_loss(pos_weights, neg_weights), metrics=['accuracy'])

# %%
# --- Data Generators ---
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    # Add more augmentations here if needed (rotation, shear, zoom, etc.)
)
val_datagen = ImageDataGenerator(rescale=1.0/255.0)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,  # Adjust batch size if needed
    class_mode='categorical'
)

valid_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32, 
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32, 
    class_mode='categorical',
    shuffle=False  # Important for evaluation
)
# Out:
# Found 7007 images belonging to 7 classes.
# Found 1502 images belonging to 7 classes.
# Found 1510 images belonging to 7 classes.

# %%
# --- Model Training ---
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    steps_per_epoch=len(train_generator),  # Use the entire training set in each epoch
    validation_steps=len(valid_generator), # Use the entire validation set
    epochs=10,  # Adjust the number of epochs as needed
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733965891.457831   14938 service.cc:148] XLA service 0x7fb600002430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733965891.457866   14938 service.cc:156]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2024-12-12 01:11:32.592943: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1733965896.837782   14938 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2024-12-12 01:11:39.109686: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_30783', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-12-12 01:11:39.251839: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_30783', 196 bytes spill stores, 196 bytes spill loads
#
# 2024-12-12 01:11:39.278094: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_30783', 448 bytes spill stores, 448 bytes spill loads
#   2/219 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - accuracy: 0.0859 - loss: 1.3468
# I0000 00:00:1733965946.004690   14938 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  46/219 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - accuracy: 0.4827 - loss: 0.7942
# 2024-12-12 01:12:38.699678: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_30783', 324 bytes spill stores, 324 bytes spill loads
#
# 2024-12-12 01:12:38.757471: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_30783', 428 bytes spill stores, 428 bytes spill loads
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.5976 - loss: 0.5799
# 2024-12-12 01:14:03.017473: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3311', 324 bytes spill stores, 324 bytes spill loads
#
# 2024-12-12 01:14:03.074597: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3311', 420 bytes spill stores, 420 bytes spill loads
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 189s 468ms/step - accuracy: 0.5979 - loss: 0.5794 - val_accuracy: 0.6478 - val_loss: 0.5456
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 159ms/step - accuracy: 0.7036 - loss: 0.4003 - val_accuracy: 0.3289 - val_loss: 3.0749
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 159ms/step - accuracy: 0.7052 - loss: 0.3794 - val_accuracy: 0.5619 - val_loss: 0.6666
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 34s 156ms/step - accuracy: 0.7347 - loss: 0.3738 - val_accuracy: 0.6511 - val_loss: 0.5585
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 160ms/step - accuracy: 0.7349 - loss: 0.3409 - val_accuracy: 0.5626 - val_loss: 0.5728
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 159ms/step - accuracy: 0.7506 - loss: 0.3293 - val_accuracy: 0.7170 - val_loss: 0.4159
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 158ms/step - accuracy: 0.7554 - loss: 0.3225 - val_accuracy: 0.7004 - val_loss: 0.4256
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 160ms/step - accuracy: 0.7714 - loss: 0.3049 - val_accuracy: 0.7157 - val_loss: 0.4933
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 34s 156ms/step - accuracy: 0.7765 - loss: 0.2944 - val_accuracy: 0.7350 - val_loss: 0.4830
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 35s 158ms/step - accuracy: 0.7805 - loss: 0.2891 - val_accuracy: 0.7264 - val_loss: 0.6312

# %%
# --- TFLite Conversion ---
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('final_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpg85ttk2g/assets
# INFO:tensorflow:Assets written to: /tmp/tmpg85ttk2g/assets
# Saved artifact at '/tmp/tmpg85ttk2g'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   140441866812784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866812080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866808912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866810320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866811200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862674336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862672752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862673280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862674864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862682080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862681024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862683664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862679616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862681552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862673808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862803296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862807344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862802944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862806112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862812272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862814912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862810864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862812800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862804352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862904240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862906000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862903536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862904768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862911984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862910928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862913568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862909520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862911456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862903184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862986512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862988272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862987040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862994256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862993200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862991792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862993728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441862985456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863068784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863070544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863068080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863069312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863076528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863075472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863072304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863076000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863067728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863216592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863218352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863215888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863217120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863220816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863221520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863224512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863215536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863266096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863267856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863265392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863266624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863273840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863358064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863357184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863273664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863357360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863363520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863366160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863362112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863364048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863372144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863440336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863439456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863439632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863446848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863445792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863448432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863444384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863446320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863522608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863521728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863453184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863521904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863529120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863528064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863526656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863533520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863637648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863636768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863636064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863636944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863644160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863643104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863645744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863641696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863643632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441863648560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441806998512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441806997632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441806997104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441806997808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807005024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807003968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807006608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807002560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807004496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807009424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807111264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807110384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807112848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807120064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807119008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807121648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807117600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807119536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807124464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807195824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807193184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807192304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807195120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807202336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807201280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807203920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807199872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807310864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807307696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807306816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807317376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807316320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807318960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807314912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807316848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807321776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807393136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807389088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807392432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807399648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807398592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807401232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807397184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807399120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807404048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807508176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807505008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807504128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807507472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807514688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807513632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807516272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807512224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807514160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807519088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807590448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807587280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807586400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807589744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807596960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807595904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807598544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807594496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807596432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807656336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807653168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807652288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807662848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807661792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807664432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807660384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807662320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807654048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866762048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866797472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866757296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866759408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807772432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807778768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807780528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807777712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807779296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807774192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866833584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866836224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866832176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866834112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866842208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866843440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866845200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866842736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866843968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866832528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807952480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807950368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807958464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807959696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807961456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807958992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807960224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441807948784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610654064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610656704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610652656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610654592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610662688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610663920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610663216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610664448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610653008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610736336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610738976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610734928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610736864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610744960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610746192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610740736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610745488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610746720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610735280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610851376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610854016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610849968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610851904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610860000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610856480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610855776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610860528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610861760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610919904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610915856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610917792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610925888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610922368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610921664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610927648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610916208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611032304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611034944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611030896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611032832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611040928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611037408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611036704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611041456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611092032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611031248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611098192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611100832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611096784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611098720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611106816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611103296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611103472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611107344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611223456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611097136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611229616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611232256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611228208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611230144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611238240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611322816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611321408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611237712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611322112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611328272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611330912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611326864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611328800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611336896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611388704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611387824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611337072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611388000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611327216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611394160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611396800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611392752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611394688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611402784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611487360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611398912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611486656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611493872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611495456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611493344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611498272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611586016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611585136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611584256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611585312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611592528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611591472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611594112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611590064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611592000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441611596928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609603904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609603024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609603200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609610416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609609360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609612000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609607952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609609888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609614816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609686176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609683888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609683712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609685472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609692688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609691632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609694272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609690224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609692160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609697088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609768448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609766160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609765104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609767744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609774960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609773904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609776544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609774432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609779360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609899872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609896352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609899168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609906384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609905328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609907968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609903920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609905856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609910784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609982144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609978976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609978096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609981440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609988656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609987600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609990240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609988128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609993056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610080800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610077632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610080096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610087312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610086256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610088896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610084848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610086784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610091712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610212224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610209056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610208176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610211520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610218736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610217680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610220320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610216272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610218208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610223136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610278112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610274944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610277408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610284624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610283568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610286208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610282160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610284096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610275824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610360384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610357216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610356336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610359680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610366896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610368480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610366368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610358096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610474192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610475952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610471376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610474720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610481936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610480880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610483520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610479472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610481408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610473136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610556464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610558224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610553648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610556992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610564208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610565792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610561744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610563680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441610555408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608574352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608576112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608573648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608574880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608582096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608580864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608584912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608580512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608583680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608573296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608688336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608690976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608686928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608688864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608696960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608698192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608692736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608697488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608698720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608687280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608754224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608756864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608752816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608754752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608762848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608759328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608758624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608763376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608764608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608888288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608886176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608894272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608890752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608890048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608894800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608896032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608884592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608967920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608970560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608966512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608968448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608976544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608973024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608972320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608977072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609044032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608966864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609050192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609052832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609048784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609050720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609058816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609055296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609055472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609059344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609159072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609049136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609165232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609167872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609163824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609165760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609173856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609242048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609240640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609241344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609164176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609247504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609250144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609246096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609248032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609256128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609389856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609388976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609256304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609389152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609246448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609395312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609397952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609393904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609395840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609403936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609422976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609422096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609400064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609422272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609429488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609428432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609431072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609427024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609428960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441609433888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607473632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607472752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607471872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607472928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607479088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607481728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607477680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607479616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607484544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607555904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607555024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607554320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607555200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607562416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607561360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607564000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607559952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607561888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607566816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607605408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607603120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607602944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607604704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607611920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607610864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607613504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607609456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607611392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607616320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607720448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607718160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607717104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607719744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607726960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607725904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607728544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607724496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607726432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607731360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607819104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607816464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607815584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607818400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607825616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607824560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607827200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607823152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607825088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607830016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607917760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607914592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607913712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607917056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607924272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607923216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607925856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607921808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607923744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441607928672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608016416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608013248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608012368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608015712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608022928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608021872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608024512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608020464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608022400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608027328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608115072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608111904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608111024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608114368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441866808384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140441608121408: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1733966387.289565   14538 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1733966387.289602   14538 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2024-12-12 01:19:47.290161: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpg85ttk2g
# 2024-12-12 01:19:47.304756: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-12-12 01:19:47.304778: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpg85ttk2g
# I0000 00:00:1733966387.511930   14538 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2024-12-12 01:19:47.552429: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-12-12 01:19:48.967758: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpg85ttk2g
# 2024-12-12 01:19:49.305702: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 2015545 microseconds.

# %%
# --- Evaluation ---
# Plot the training loss and accuracy curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training and Validation Loss")

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training and Validation Accuracy")
plt.show()

# %%
# Predict using the model
predicted_vals = model.predict(test_generator, steps=len(test_generator))
print("Predictions completed.")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/48 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 2024-12-12 01:20:31.005646: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3273', 40 bytes spill stores, 40 bytes spill loads
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 283ms/step
# Predictions completed.

# %%
# --- ROC Curve ---
def get_roc_curve(labels, predicted_vals, generator):
    """Compute ROC curve and AUC for each label."""
    auc_roc_scores = {}
    true_labels = generator.labels
    if len(true_labels.shape) == 1:
        from tensorflow.keras.utils import to_categorical
        true_labels = to_categorical(true_labels, num_classes=len(labels))

    for idx, label in enumerate(labels):
        true_vals = true_labels[:, idx]
        preds = predicted_vals[:, idx]
        auc = roc_auc_score(true_vals, preds)
        auc_roc_scores[label] = auc
        fpr, tpr, _ = roc_curve(true_vals, preds)
        plt.figure()
        plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'ROC Curve for {label}')
        plt.legend(loc='lower right')
        plt.show()
    return auc_roc_scores

auc_rocs = get_roc_curve(labels, predicted_vals, test_generator)
print("AUC-ROC scores:", auc_rocs)
# Out:
# AUC-ROC scores: {'bkl': np.float64(0.9341095890410959), 'nv': np.float64(0.9532839134794442), 'df': np.float64(0.9042296501312895), 'mel': np.float64(0.9151772415847483), 'vasc': np.float64(0.8805962163535921), 'bcc': np.float64(0.9239024640636816), 'akiec': np.float64(0.9961815738025415)}
